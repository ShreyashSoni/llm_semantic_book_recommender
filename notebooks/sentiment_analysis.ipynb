# %% [markdown]
# # Emotion Analysis
#
# ## Data Loading

# %%
import pandas as pd

books = pd.read_csv("../data/books_with_categories.csv")
books.head()
# Out:
#           isbn13      isbn10                title  \
# 0  9780002005883  0002005883               Gilead
# 1  9780002261982  0002261987         Spider's Web
# 2  9780006178736  0006178731       Rage of angels
# 3  9780006280897  0006280897       The Four Loves
# 4  9780006280934  0006280935  The Problem of Pain
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2                   Sidney Sheldon                        Fiction
# 3              Clive Staples Lewis                 Christian life
# 4              Clive Staples Lewis                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=FKo2T...
# 3  http://books.google.com/books/content?id=XhQ5X...
# 4  http://books.google.com/books/content?id=Kk-uV...
#
#                                          description  published_year  \
# 0  A NOVEL THAT READERS and critics have been eag...          2004.0
# 1  A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2  A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3  Lewis' work on the nature of love divides love...          2002.0
# 4  "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
#
#    average_rating  num_pages  ratings_count     title_and_subtitle  \
# 0            3.85      247.0          361.0                 Gilead
# 1            3.83      241.0         5164.0  Spider's Web: A Novel
# 2            3.93      512.0        29532.0         Rage of angels
# 3            4.15      170.0        33684.0         The Four Loves
# 4            4.09      176.0        37569.0    The Problem of Pain
#
#                                   tagged_description simple_categories
# 0  9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1  9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2  9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3  9780006280897 Lewis' work on the nature of lov...        Nonfiction
# 4  9780006280934 "In The Problem of Pain, C.S. Le...        Nonfiction

# %% [markdown]
# ## Emotion Classifier Setup

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

classifier = pipeline("text-classification", 
                model="j-hartmann/emotion-english-distilroberta-base", 
                top_k=None)

classifier("I love this!")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/329M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/294 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/329M [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Device set to use mps:0
# [[{'label': 'joy', 'score': 0.9771687984466553},
#   {'label': 'surprise', 'score': 0.008528688922524452},
#   {'label': 'neutral', 'score': 0.005764600355178118},
#   {'label': 'anger', 'score': 0.004419785924255848},
#   {'label': 'sadness', 'score': 0.002092392183840275},
#   {'label': 'disgust', 'score': 0.0016119939973577857},
#   {'label': 'fear', 'score': 0.0004138523945584893}]]

# %%
books["description"][0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.'

# %%
classifier(books["description"][0])
# Out:
# [[{'label': 'fear', 'score': 0.6548415422439575},
#   {'label': 'neutral', 'score': 0.16985175013542175},
#   {'label': 'sadness', 'score': 0.11640891432762146},
#   {'label': 'surprise', 'score': 0.020700635388493538},
#   {'label': 'disgust', 'score': 0.01910071074962616},
#   {'label': 'joy', 'score': 0.015161288902163506},
#   {'label': 'anger', 'score': 0.003935148473829031}]]

# %% [markdown]
# ## Sentence-Level Analysis Exploration

# %%
classifier(books["description"][0].split("."))
# Out:
# [[{'label': 'surprise', 'score': 0.7296026349067688},
#   {'label': 'neutral', 'score': 0.14038576185703278},
#   {'label': 'fear', 'score': 0.06816215068101883},
#   {'label': 'joy', 'score': 0.04794244095683098},
#   {'label': 'anger', 'score': 0.009156351909041405},
#   {'label': 'disgust', 'score': 0.0026284761261194944},
#   {'label': 'sadness', 'score': 0.0021221614442765713}],
#  [{'label': 'neutral', 'score': 0.4493712782859802},
#   {'label': 'disgust', 'score': 0.27359122037887573},
#   {'label': 'joy', 'score': 0.1090829148888588},
#   {'label': 'sadness', 'score': 0.09362715482711792},
#   {'label': 'anger', 'score': 0.04047822207212448},
#   {'label': 'surprise', 'score': 0.026970189064741135},
#   {'label': 'fear', 'score': 0.006879066117107868}],
#  [{'label': 'neutral', 'score': 0.6462162137031555},
#   {'label': 'sadness', 'score': 0.24273313581943512},
#   {'label': 'disgust', 'score': 0.04342268779873848},
#   {'label': 'surprise', 'score': 0.02830052375793457},
#   {'label': 'joy', 'score': 0.014211435802280903},
#   {'label': 'fear', 'score': 0.014084112830460072},
#   {'label': 'anger', 'score': 0.011031885631382465}],
#  [{'label': 'fear', 'score': 0.9281684160232544},
#   {'label': 'anger', 'score': 0.03219074755907059},
#   {'label': 'neutral', 'score': 0.0128086619079113},
#   {'label': 'sadness', 'score': 0.008756855502724648},
#   {'label': 'surprise', 'score': 0.00859788991510868},
#   {'label': 'disgust', 'score': 0.00843181274831295},
#   {'label': 'joy', 'score': 0.001045581535436213}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104185789823532},
#   {'label': 'disgust', 'score': 0.006480598822236061},
#   {'label': 'fear', 'score': 0.005393998231738806},
#   {'label': 'surprise', 'score': 0.0022869419772177935},
#   {'label': 'anger', 'score': 0.0018428867915645242},
#   {'label': 'joy', 'score': 0.0017338788602501154}],
#  [{'label': 'joy', 'score': 0.9327975511550903},
#   {'label': 'disgust', 'score': 0.037717584520578384},
#   {'label': 'neutral', 'score': 0.0158919058740139},
#   {'label': 'sadness', 'score': 0.006444538943469524},
#   {'label': 'anger', 'score': 0.005025008227676153},
#   {'label': 'surprise', 'score': 0.001581208547577262},
#   {'label': 'fear', 'score': 0.0005423097754828632}],
#  [{'label': 'joy', 'score': 0.6528699398040771},
#   {'label': 'neutral', 'score': 0.25427526235580444},
#   {'label': 'surprise', 'score': 0.06808330118656158},
#   {'label': 'sadness', 'score': 0.00990901980549097},
#   {'label': 'disgust', 'score': 0.0065122139640152454},
#   {'label': 'anger', 'score': 0.0048213256523013115},
#   {'label': 'fear', 'score': 0.003529029432684183}],
#  [{'label': 'neutral', 'score': 0.5494773983955383},
#   {'label': 'sadness', 'score': 0.11169009655714035},
#   {'label': 'disgust', 'score': 0.1040065661072731},
#   {'label': 'surprise', 'score': 0.07876540720462799},
#   {'label': 'anger', 'score': 0.06413351744413376},
#   {'label': 'fear', 'score': 0.05136270821094513},
#   {'label': 'joy', 'score': 0.04056433215737343}]]

# %%
sentences = books["description"][0].split(".")
predictions = classifier(sentences)

# %%
print(sentences[0])
print(predictions[0])
# Out:
# A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives
# [{'label': 'surprise', 'score': 0.7296026349067688}, {'label': 'neutral', 'score': 0.14038576185703278}, {'label': 'fear', 'score': 0.06816215068101883}, {'label': 'joy', 'score': 0.04794244095683098}, {'label': 'anger', 'score': 0.009156351909041405}, {'label': 'disgust', 'score': 0.0026284761261194944}, {'label': 'sadness', 'score': 0.0021221614442765713}]

# %%
sorted(predictions[0], key=lambda x: x["label"])
# Out:
# [{'label': 'anger', 'score': 0.009156351909041405},
#  {'label': 'disgust', 'score': 0.0026284761261194944},
#  {'label': 'fear', 'score': 0.06816215068101883},
#  {'label': 'joy', 'score': 0.04794244095683098},
#  {'label': 'neutral', 'score': 0.14038576185703278},
#  {'label': 'sadness', 'score': 0.0021221614442765713},
#  {'label': 'surprise', 'score': 0.7296026349067688}]

# %% [markdown]
# ## Create Score Aggregation Function

# %%
import numpy as np

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

def calculate_max_emotion_scores(predictions):
    per_emotion_scores = {label: [] for label in emotion_labels}
    for prediction in predictions:
        sorted_predictions = sorted(prediction, key=lambda x: x["label"])
        for index, label in enumerate(emotion_labels):
            per_emotion_scores[label].append(sorted_predictions[index]["score"])
    return {label: np.max(scores) for label, scores in per_emotion_scores.items()}

# %%
for i in range(10):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])

# %%
emotion_scores
# Out:
# {'anger': [np.float64(0.06413351744413376),
#   np.float64(0.6126181483268738),
#   np.float64(0.06413351744413376),
#   np.float64(0.3514839708805084),
#   np.float64(0.0814121663570404),
#   np.float64(0.2322244644165039),
#   np.float64(0.5381844639778137),
#   np.float64(0.06413351744413376),
#   np.float64(0.30067044496536255),
#   np.float64(0.06413351744413376)],
#  'disgust': [np.float64(0.27359122037887573),
#   np.float64(0.34828507900238037),
#   np.float64(0.1040065661072731),
#   np.float64(0.15072253346443176),
#   np.float64(0.18449512124061584),
#   np.float64(0.7271751761436462),
#   np.float64(0.15585516393184662),
#   np.float64(0.1040065661072731),
#   np.float64(0.2794809639453888),
#   np.float64(0.1779271811246872)],
#  'fear': [np.float64(0.9281684160232544),
#   np.float64(0.9425276517868042),
#   np.float64(0.9723208546638489),
#   np.float64(0.36070647835731506),
#   np.float64(0.0950433760881424),
#   np.float64(0.05136270821094513),
#   np.float64(0.7474286556243896),
#   np.float64(0.40449538826942444),
#   np.float64(0.9155242443084717),
#   np.float64(0.05136270821094513)],
#  'joy': [np.float64(0.9327975511550903),
#   np.float64(0.7044215798377991),
#   np.float64(0.7672368884086609),
#   np.float64(0.2518807053565979),
#   np.float64(0.04056433215737343),
#   np.float64(0.04337577149271965),
#   np.float64(0.8725650906562805),
#   np.float64(0.04056433215737343),
#   np.float64(0.04056433215737343),
#   np.float64(0.04056433215737343)],
#  'sadness': [np.float64(0.6462162137031555),
#   np.float64(0.8879395127296448),
#   np.float64(0.5494773983955383),
#   np.float64(0.7326862215995789),
#   np.float64(0.8843894600868225),
#   np.float64(0.6213929057121277),
#   np.float64(0.712194561958313),
#   np.float64(0.5494773983955383),
#   np.float64(0.8402897715568542),
#   np.float64(0.8603722453117371)],
#  'surprise': [np.float64(0.9671575427055359),
#   np.float64(0.11169009655714035),
#   np.float64(0.11169009655714035),
#   np.float64(0.11169009655714035),
#   np.float64(0.4758807420730591),
#   np.float64(0.11169009655714035),
#   np.float64(0.4079994261264801),
#   np.float64(0.8202821612358093),
#   np.float64(0.3544594943523407),
#   np.float64(0.11169009655714035)],
#  'neutral': [np.float64(0.7296026349067688),
#   np.float64(0.25254467129707336),
#   np.float64(0.07876540720462799),
#   np.float64(0.07876540720462799),
#   np.float64(0.07876540720462799),
#   np.float64(0.27190253138542175),
#   np.float64(0.07876540720462799),
#   np.float64(0.2344880849123001),
#   np.float64(0.13561506569385529),
#   np.float64(0.07876540720462799)]}

# %%
from tqdm import tqdm

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

for i in tqdm(range(len(books))):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# 100%|██████████| 5197/5197 [03:25<00:00, 25.26it/s]

# %%
emotions_df = pd.DataFrame(emotion_scores)
emotions_df["isbn13"] = isbn
emotions_df.head()
# Out:
#       anger   disgust      fear       joy   sadness  surprise   neutral  \
# 0  0.064134  0.273591  0.928168  0.932798  0.646216  0.967158  0.729603
# 1  0.612618  0.348285  0.942528  0.704422  0.887940  0.111690  0.252545
# 2  0.064134  0.104007  0.972321  0.767237  0.549477  0.111690  0.078765
# 3  0.351484  0.150723  0.360706  0.251881  0.732686  0.111690  0.078765
# 4  0.081412  0.184495  0.095043  0.040564  0.884389  0.475881  0.078765
#
#           isbn13
# 0  9780002005883
# 1  9780002261982
# 2  9780006178736
# 3  9780006280897
# 4  9780006280934

# %%
books = pd.merge(books, emotions_df, on = "isbn13")

# %%
books.head()
# Out:
#           isbn13      isbn10                title  \
# 0  9780002005883  0002005883               Gilead
# 1  9780002261982  0002261987         Spider's Web
# 2  9780006178736  0006178731       Rage of angels
# 3  9780006280897  0006280897       The Four Loves
# 4  9780006280934  0006280935  The Problem of Pain
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2                   Sidney Sheldon                        Fiction
# 3              Clive Staples Lewis                 Christian life
# 4              Clive Staples Lewis                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=FKo2T...
# 3  http://books.google.com/books/content?id=XhQ5X...
# 4  http://books.google.com/books/content?id=Kk-uV...
#
#                                          description  published_year  \
# 0  A NOVEL THAT READERS and critics have been eag...          2004.0
# 1  A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2  A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3  Lewis' work on the nature of love divides love...          2002.0
# 4  "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
#
#    average_rating  num_pages  ...     title_and_subtitle  \
# 0            3.85      247.0  ...                 Gilead
# 1            3.83      241.0  ...  Spider's Web: A Novel
# 2            3.93      512.0  ...         Rage of angels
# 3            4.15      170.0  ...         The Four Loves
# 4            4.09      176.0  ...    The Problem of Pain
#
#                                   tagged_description simple_categories  \
# 0  9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1  9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2  9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3  9780006280897 Lewis' work on the nature of lov...        Nonfiction
# 4  9780006280934 "In The Problem of Pain, C.S. Le...        Nonfiction
#
#       anger   disgust      fear       joy   sadness  surprise   neutral
# 0  0.064134  0.273591  0.928168  0.932798  0.646216  0.967158  0.729603
# 1  0.612618  0.348285  0.942528  0.704422  0.887940  0.111690  0.252545
# 2  0.064134  0.104007  0.972321  0.767237  0.549477  0.111690  0.078765
# 3  0.351484  0.150723  0.360706  0.251881  0.732686  0.111690  0.078765
# 4  0.081412  0.184495  0.095043  0.040564  0.884389  0.475881  0.078765
#
# [5 rows x 21 columns]

# %%
books.to_csv("../data/books_with_emotions.csv", index = False)
